# %%
import sys
import os
import numpy as np
import torch 
import torch.nn as nn
import matplotlib.pyplot as plt
import seaborn as sns

sys.path.append('../')

from data.utils import *
from data.classes import *
from data.dataset import SuperResolutionDataset 
from torch.utils.data import Dataset, DataLoader

# %%
ds = SuperResolutionDataset('/fs/nexus-scratch/ayang115/dmv_dataset/datasets/goes_landsat')

# %%
sample, label = ds[0]
fig, axs = plt.subplots(1, 2)
axs[0].imshow(sample[0])
axs[0].set_title('sample')
axs[1].imshow(label[0])
axs[1].set_title('target')
# Out:
# Text(0.5, 1.0, 'target')

# %%
label
# Out:
# '/fs/nexus-scratch/ayang115/dmv_dataset/datasets/goes_landsat/data/0_target.npy'
