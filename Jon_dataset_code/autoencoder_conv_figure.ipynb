# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import svgutils.compose as sc
from IPython.display import SVG
import svgutils.transform as sg

# %%
figsave_path = '/glade/work/jstarfeldt/autoencoder'

# %%
fig = plt.figure(figsize=(8.,4.))

ax = fig.add_axes([0., 0., 1., 1.])

#ax.set_title('Convolutional Autoencoder Model Architecture', x=1.55, y=0.75, fontsize=24)

#ax.text(0.08, 0.5, '    Input\n  Feature\n(32x32x1)', fontsize=18, transform=ax.transAxes)
#ax.text(0.13, -0.14, '  Convolutional Layer,\n    BatchNorm, ReLU\n       (32x32x16)', fontsize=18, transform=ax.transAxes)
#ax.text(0.42, 0.42, '     Max\n   Pooling\n(16x16x16)', fontsize=18, transform=ax.transAxes)
#ax.text(0.54, -0.16, '  Convolutional Layer,\n    BatchNorm, ReLU\n       (16x16x32)', fontsize=18, transform=ax.transAxes)
#ax.text(0.88, 0.32, '   Max\n Pooling\n(8x8x32)', fontsize=18, transform=ax.transAxes)
#ax.text(1.0, -0.2, '  Convolutional Layer,\n    BatchNorm, ReLU\n       (8x8x64)', fontsize=18, transform=ax.transAxes)
#ax.text(1.38, 0.2, '   Max\n Pooling\n(4x4x64)', fontsize=18, transform=ax.transAxes)
#ax.text(1.5, -0.25, '  Convolutional Layer,\n    BatchNorm, ReLU\n       (4x4x64)', fontsize=18, transform=ax.transAxes)
#ax.text(1.88, 0.15, '    Max\nUnpooling\n(8x8x64)', fontsize=18, transform=ax.transAxes)
#ax.text(1.97, -0.35, '  Convolutional Layer,\n    BatchNorm, ReLU\n       (8x8x32)', fontsize=18, transform=ax.transAxes)
#ax.text(2.34, 0.12, '    Max\nUnpooling\n(16x16x32)', fontsize=18, transform=ax.transAxes)
#ax.text(2.39, -0.45, '  Convolutional Layer,\n    BatchNorm, ReLU\n       (16x16x16)', fontsize=18, transform=ax.transAxes)
#ax.text(2.75, 0.09, '    Max\nUnpooling\n(32x32x16)', fontsize=18, transform=ax.transAxes)
#ax.text(2.82, -0.52, '  Convolutional\n Layer, Output\n    (32x32x1)', fontsize=18, transform=ax.transAxes)

#ax.set_title('Convolutional Autoencoder Model Architecture', x=1.7, y=0.85, fontsize=32)

ax.text(0.08, -0.12, '   Input\n Feature\n(32x32x1)', fontsize=20, transform=ax.transAxes)
ax.text(0.26, -0.21, '  Convolutional Layer,\n  BatchNorm, ReLU, Max\n  Pooling (16x16x16)', fontsize=20, transform=ax.transAxes)
ax.text(0.7, 0.51, '  Convolutional Layer,\n BatchNorm, ReLU, Max\n     Pooling (8x8x32)', fontsize=20, transform=ax.transAxes)
ax.text(1.12, 0.35, '  Convolutional Layer,\nBatchNorm, ReLU, Max\n      Pooling (4x4x64)', fontsize=20, transform=ax.transAxes)
ax.text(1.62, 0.32, ' Convolutional Layer,\n   BatchNorm, ReLU,\n     Max Unpooling\n       (8x8x64)', fontsize=20, transform=ax.transAxes)
ax.text(2.08, 0.27, ' Convolutional Layer,\n   BatchNorm, ReLU,\n    Max Unpooling\n     (16x16x32)', fontsize=20, transform=ax.transAxes)
ax.text(2.46, 0.25, '  Convolutional Layer,\n   BatchNorm, ReLU,\n    Max Unpooling\n     (32x32x16)', fontsize=20, transform=ax.transAxes)
ax.text(2.86, 0.2, ' Convolutional\n Layer, Output\n   (32x32x1)', fontsize=20, transform=ax.transAxes)


ax.axis('off')

ax.tick_params(axis='both', bottom=False, left=False, labelbottom=False, labelleft=False)

plt.savefig(f'{figsave_path}/cnn_text_no_pool.svg', bbox_inches='tight', dpi=500, transparent=True)
plt.close()

sc.Figure("16in", "8in", 
          sc.Panel(sc.SVG(f"{figsave_path}/nn_no_pool.svg").scale(0.008).move(7.3,2)),\
          sc.Panel(sc.SVG(f"{figsave_path}/cnn_text_no_pool.svg").scale(0.008))
         ).save(f"{figsave_path}/autoencoder_architecture_no_pool.svg")
SVG(f'{figsave_path}/autoencoder_architecture_no_pool.svg')
