# %%
import sys
import os
import numpy as np
import torch 
import torch.nn as nn

sys.path.append('../')

from data.utils import *
from data.classes import *
from torch.utils.data import Dataset, DataLoader
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 9
#       5 import torch.nn as nn
#       7 sys.path.append('../')
# ----> 9 from data.utils import *
#      10 from data.classes import *
#      11 from torch.utils.data import Dataset, DataLoader
#
# File ~/ML_UH_datasets/super_resolution/notebooks/../data/utils.py:5
#       3 import numpy as np
#       4 import pandas as pd
# ----> 5 import xarray as xr
#       6 import rioxarray as rxr
#       7 import seaborn as sns
#
# File ~/miniconda3/envs/csml/lib/python3.9/site-packages/xarray/__init__.py:3
#       1 from importlib.metadata import version as _version
# ----> 3 from xarray import groupers, testing, tutorial
#       4 from xarray.backends.api import (
#       5     load_dataarray,
#       6     load_dataset,
#    (...)
#      10     save_mfdataset,
#      11 )
# ...

# %%
sample = '/fs/nexus-scratch/ayang115/dmv_dataset/numpy/GOES_Landsat_image_0-0000000000-0000000000.npy'
np_sample = np.load(sample)

tiles = create_tiles(np_sample, 128, 128, 128, True)
